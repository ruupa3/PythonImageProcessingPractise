# %%
pip install scikit-image
# Out:
# ...
#   Obtaining dependency information for scikit-image from https://files.pythonhosted.org/packages/32/b2/1811645651153407f1e715b75afe9962d87582bee70b42c8671c255f8fe6/scikit_image-0.21.0-cp39-cp39-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#      - -------------------------------------- 0.1/2.1 MB 1.7 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.2/2.1 MB 2.3 MB/s eta 0:00:01
#      ------- -------------------------------- 0.4/2.1 MB 2.7 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.6/2.1 MB 3.1 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.8/2.1 MB 3.5 MB/s eta 0:00:01
#      -------------------- ------------------- 1.1/2.1 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 1.3/2.1 MB 3.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.5/2.1 MB 4.0 MB/s eta 0:00:01
# ...

# %%
from skimage.io import imread, imshow
from skimage.color import rgb2gray

# %%
img1 = rgb2gray(imread("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif"))

# %%
img = imread("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif")
imshow(img)
imshow(img, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# C:\Users\Tribal Development 1\AppData\Local\Programs\Python\Python39\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:162: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   ax.get_figure().tight_layout()

# %%
img1_t = 1.0 * (img1 > 0.5)
# first pass a threshold to our image to get the necessary features

# %%
imshow(img1_t, cmap='gray')

# %%
imshow(img1)

# %%
# Pass the second image through a higher threshold. This may be associated with a different color grading of the images.

# %%
img2 = rgb2gray(imread("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_L_5thJan2022_RGB_ND.tif"))
img2_t = 1.0 * (img2 > 0.6)
imshow(img2_t, cmap='gray');

# %%
imshow(img2)

# %%
img3 = rgb2gray(imread("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_L_11thFeb2021_RGB_ND.tif"))
img3_t = 1.0 * (img3 > 0.6)
imshow(img3_t, cmap='gray');

# %%
imshow(img3)

# %%
# In order for us to see which pixels are changed between these images, 
# we perform image differencing which is simply what it is, we take the differences in the two arrays:

# %%
from skimage.util import invert
diff = img1_t - img2_t
diff_i = invert(diff)
imshow(diff_i);

# %%
# from the resulting image, we have gray areas which account for the ones in the inital image
# pass a threshold given to us by values of 2 in the image

# %%
diff = img1_t - img2_t
diff_i = invert(diff) >= 2.00
imshow(diff_i);

# %%
(diff_i.sum()/img1.size)*100
# Out:
# 0.03176007756052713

# %%
pip install image
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for image: filename=image-1.5.33-py2.py3-none-any.whl size=19490 sha256=7a7c62804793304d6f37897a801461f03244766ceb3b1e932ad5c80078317fb4
#   Stored in directory: c:\users\tribal development 1\appdata\local\pip\cache\wheels\14\4c\7c\d9b5c35a149d3bc8c72c7e92372913ff7dac9c6bd94bd1b8c9
# Successfully built image
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import image

# %%
blue = image.open("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_Landsat_Jan2023_B2.tif")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 blue = image.open("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_Landsat_Jan2023_B2.tif")
#
# AttributeError: module 'image' has no attribute 'open'

# %%
from PIL import Image

# %%
im1 = Image.open(r"C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_Landsat_Jan2023_B2.tif")
# Out:
# C:\Users\Tribal Development 1\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:3157: DecompressionBombWarning: Image size (101732521 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
im1 = Image.open(r'C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif')
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 im1 = Image.open(r"C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:3280, in open(fp, mode, formats)
#    3278     warnings.warn(message)
#    3279 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3280 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file 'C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif'

# %%
im1 = Image.open(r'C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif')
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 im1 = Image.open(r'C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:3280, in open(fp, mode, formats)
#    3278     warnings.warn(message)
#    3279 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3280 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file 'C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif'

# %%
im1 = Image.open("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 im1 = Image.open("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:3280, in open(fp, mode, formats)
#    3278     warnings.warn(message)
#    3279 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3280 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file 'C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_District_Jan2023_RGB.tif'

# %%
# Need to convert each channel into a luminosity channel

# %%
blue = Image.open("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_Landsat_Jan2023_B2.tif").convert('L')

# %%
green = Image.open("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_Landsat_Jan2023_B3.tif").convert('L')

# %%
red = Image.open("C:/Users/Tribal Development 1/Desktop/Downloaded_Satellite_Data/Puri_Landsat_Jan2023/Puri_Landsat_Jan2023_B4.tif").convert('L')
